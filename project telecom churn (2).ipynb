# %% [markdown]
# # importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # importing the data

# %%
data=pd.read_csv("C:\\Users\\Dharani\\Downloads\\Telco Customer Churn.csv")

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
#checking the size of the rows and columns
data.shape
# Out:
# (7043, 21)

# %%
#column names
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#first five rows and columns from the dataset
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#last five rows and columns from dataset
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#checking the data contains any null value
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
#understanding the data by gender wise
data['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
#sns used for data visualisation
sns.countplot(x="gender",hue="gender",data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
data['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
sns.countplot(x="SeniorCitizen",hue="SeniorCitizen",data=data)
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
data['Dependents'].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
sns.countplot(x="Dependents",hue="Dependents",data=data)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
data['tenure'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
data['tenure'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['PhoneService'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
sns.countplot(x="PhoneService",hue="PhoneService",data=data)
# Out:
# <AxesSubplot:xlabel='PhoneService', ylabel='count'>

# %%
c=pd.DataFrame(data['MultipleLines'].value_counts())
c
# Out:
#                   MultipleLines
# No                         3390
# Yes                        2971
# No phone service            682

# %%
c.plot.bar(color="green", title="multiplelines")
# Out:
# <AxesSubplot:title={'center':'multiplelines'}>

# %%
m=pd.DataFrame(data['InternetService'].value_counts())
m
# Out:
#              InternetService
# Fiber optic             3096
# DSL                     2421
# No                      1526

# %%
m.plot.bar(color="red", title="person using internet service ")
# Out:
# <AxesSubplot:title={'center':'person using internet service '}>

# %%
l=pd.DataFrame(data['OnlineSecurity'].value_counts())
l
# Out:
#                      OnlineSecurity
# No                             3498
# Yes                            2019
# No internet service            1526

# %%
l.plot.bar(color="purple",title="person has online security")
# Out:
# <AxesSubplot:title={'center':'person has online security'}>

# %%
g=pd.DataFrame(data['DeviceProtection'].value_counts())

# %%
g
# Out:
#                      DeviceProtection
# No                               3095
# Yes                              2422
# No internet service              1526

# %%
g.plot.bar(color="green",title="person has device protection")
# Out:
# <AxesSubplot:title={'center':'person has device protection'}>

# %%
k=pd.DataFrame(data['TechSupport'].value_counts())
k
# Out:
#                      TechSupport
# No                          3473
# Yes                         2044
# No internet service         1526

# %%
g.plot.bar(color="green",title="person has device protection")
# Out:
# <AxesSubplot:title={'center':'person has device protection'}>

# %%
h=pd.DataFrame(data['Contract'].value_counts())
h
# Out:
#                 Contract
# Month-to-month      3875
# Two year            1695
# One year            1473

# %%
h.plot.bar(color="red",title="contract")
# Out:
# <AxesSubplot:title={'center':'contract'}>

# %%
y=pd.DataFrame(data['PaperlessBilling'].value_counts())
y
# Out:
#      PaperlessBilling
# Yes              4171
# No               2872

# %%
y.plot.bar(color="red",title="paperlessbilling")
# Out:
# <AxesSubplot:title={'center':'paperlessbilling'}>

# %%
z=pd.DataFrame(data['PaymentMethod'].value_counts())
z
# Out:
#                            PaymentMethod
# Electronic check                    2365
# Mailed check                        1612
# Bank transfer (automatic)           1544
# Credit card (automatic)             1522

# %%
z.plot.bar(color="red",title="paymentmethod")
# Out:
# <AxesSubplot:title={'center':'paymentmethod'}>

# %%
data['MonthlyCharges'].mean()
# Out:
# 64.76169246059922

# %%
data['MonthlyCharges'].max()
# Out:
# 118.75

# %%
data['MonthlyCharges'].min()
# Out:
# 18.25

# %%
data['MonthlyCharges'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['TotalCharges'].max()
# Out:
# '999.9'

# %%
r=pd.DataFrame(data['Churn'].value_counts())
r
# Out:
#      Churn
# No    5174
# Yes   1869

# %%
r.plot.bar(color="red",title="paymentmethod")
# Out:
# <AxesSubplot:title={'center':'paymentmethod'}>

# %%
data.boxplot(column='MonthlyCharges')
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # how many  churning has yes?

# %%
sa=pd.DataFrame(data[['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges']]
                [data['Churn']=="Yes"])

# %%
sa
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 2             Yes            No             DSL            Yes          Yes
# ...

# %%
sa.shape
# Out:
# (1869, 20)

# %% [markdown]
# # how many  churning has no ?

# %%
ra=pd.DataFrame(data[['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges']]
                [data['Churn']=="No"])

# %%
ra
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0              No  No phone service             DSL                   No
# ...

# %%
ra.shape
# Out:
# (5174, 20)

# %% [markdown]
# # how many has more than average monthly charges?

# %%
rd=pd.DataFrame(data[['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'TotalCharges','Churn']]
               [data['MonthlyCharges']>=64.761692460599])

# %%
rd
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...          ...     ...            ...     ...        ...     ...
# 7035  8456-QDAVC    Male              0      No         No      19
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 4             Yes            No     Fiber optic             No           No
# ...

# %% [markdown]
# # morethan average monthly charges who turnes into churn?

# %%
kj=data[(data["MonthlyCharges"]>=64.76169246059922)&(data["Churn"]=="Yes")]

# %%
kj
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# ...          ...     ...            ...     ...        ...     ...
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4             Yes            No     Fiber optic             No  ...
# ...

# %%
kj.shape
# Out:
# (1355, 21)

# %% [markdown]
# # morethan average monthly charges who turnes into churning no?¶

# %%
kh=data[(data["MonthlyCharges"]>=64.76169246059922)&(data["Churn"]=="No")]

# %%
kh
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6     1452-KIOVK    Male              0      No        Yes      22
# 12    8091-TTVAX    Male              0     Yes         No      58
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7035  8456-QDAVC    Male              0      No         No      19
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 6             Yes           Yes     Fiber optic             No  ...
# ...

# %%
kh.shape
# Out:
# (2568, 21)

# %% [markdown]
# # how many male person has morethan average monthlycharges and churning yes ?

# %%
kj=data[(data["MonthlyCharges"]>=64.76169246059922)&(data["Churn"]=="Yes")&(data["gender"]=="Male")]

# %%
kj
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 13    0280-XJGEX   Male              0      No         No      49
# 26    6467-CHFZW   Male              0     Yes        Yes      47
# 36    6047-YHPVI   Male              0      No         No       5
# 38    5380-WJKOV   Male              0      No         No      34
# 55    1658-BYGOY   Male              1      No         No      18
# ...          ...    ...            ...     ...        ...     ...
# 7006  0093-XWZFY   Male              0      No         No      40
# 7009  7703-ZEKEF   Male              0      No         No      23
# 7018  1122-JWTJW   Male              0     Yes        Yes       1
# 7032  6894-LFHLY   Male              1      No         No       1
# 7041  8361-LTMKD   Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 13            Yes           Yes     Fiber optic             No  ...
# ...

# %%
kj.shape
# Out:
# (657, 21)

# %% [markdown]
# # how many male person has morethan average monthlycharges and churning no ?

# %%
kk=data[(data["MonthlyCharges"]>=64.76169246059922)&(data["Churn"]=="No")&(data["gender"]=="Male")]

# %%
kk
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 6     1452-KIOVK   Male              0      No        Yes      22
# 12    8091-TTVAX   Male              0     Yes         No      58
# 14    5129-JLPIS   Male              0      No         No      25
# 17    9959-WOFKT   Male              0      No        Yes      71
# 28    5248-YGIJN   Male              0     Yes         No      72
# ...          ...    ...            ...     ...        ...     ...
# 7027  0550-DCXLH   Male              0      No         No      13
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 6             Yes           Yes     Fiber optic             No  ...
# ...

# %%
kk.shape
# Out:
# (1300, 21)

# %% [markdown]
# # how many female person has morethan average monthlycharges and churning yes ?

# %%
kt=data[(data["MonthlyCharges"]>=64.76169246059922)&(data["Churn"]=="Yes")&(data["gender"]=="Female")]

# %%
kt
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 39    8168-UQWWF  Female              0      No         No      11
# 47    7760-OYPDY  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 6996  4174-LPGTI  Female              0     Yes        Yes      41
# 7008  1980-KXVPM  Female              1      No         No       3
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4             Yes            No     Fiber optic             No  ...
# ...

# %% [markdown]
# # how many has contract one year?

# %%
ab=data[(data["Contract"]=="One year")]

# %%
ab
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 9     6388-TABGU    Male              0      No        Yes      62
# 12    8091-TTVAX    Male              0     Yes         No      58
# 16    8191-XWSZG  Female              0      No         No      52
# ...          ...     ...            ...     ...        ...     ...
# 7022  7203-OYKCT    Male              0      No         No      72
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %% [markdown]
# # how many male person has contract one year?

# %%
ac=data[(data["Contract"]=="One year")&(data["gender"]=="Male")]

# %%
ac
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 3     7795-CFOCW   Male              0      No         No      45
# 9     6388-TABGU   Male              0      No        Yes      62
# 12    8091-TTVAX   Male              0     Yes         No      58
# 21    1680-VDCWW   Male              0     Yes         No      12
# ...          ...    ...            ...     ...        ...     ...
# 7005  9347-AERRL   Male              0     Yes         No      23
# 7021  1699-HPSBG   Male              0      No         No      12
# 7022  7203-OYKCT   Male              0      No         No      72
# 7031  3605-JISKB   Male              1     Yes         No      55
# 7038  6840-RESVB   Male              0     Yes        Yes      24
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %%
ac.shape
# Out:
# (755, 21)

# %% [markdown]
# # how many female person has contract one year?

# %%
ac=data[(data["Contract"]=="One year")&(data["gender"]=="Female")]

# %%
ac
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 16    8191-XWSZG  Female              0      No         No      52
# 32    6827-IEAUQ  Female              0     Yes        Yes      27
# 42    9867-JCZSP  Female              0     Yes        Yes      17
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 56    8769-KKTPH  Female              0     Yes        Yes      63
# ...          ...     ...            ...     ...        ...     ...
# 6994  0804-YGEQV  Female              0     Yes        Yes      43
# 6996  4174-LPGTI  Female              0     Yes        Yes      41
# 7000  0052-YNYOT  Female              0      No         No      67
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 16            Yes                No              No  No internet service  ...
# ...

# %%
ac.shape
# Out:
# (718, 21)

# %% [markdown]
# # how many has contract two year?

# %%
ac=data[data["Contract"]=="Two year"]

# %%
ac
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 11    7469-LKBCI    Male              0      No         No      16
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 23    3638-WEABW  Female              0     Yes         No      58
# 28    5248-YGIJN    Male              0     Yes         No      72
# ...          ...     ...            ...     ...        ...     ...
# 7017  4807-IZYOZ  Female              0      No         No      51
# 7019  9710-NJERN  Female              0      No         No      39
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7037  2569-WGERO  Female              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 11            Yes            No              No  No internet service  ...
# ...

# %%
ac.shape
# Out:
# (1695, 21)

# %% [markdown]
# # how many male person has contract two year?

# %%
ac=data[(data["Contract"]=="Two year")&(data["gender"]=="Male")]

# %%
ac
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 11    7469-LKBCI   Male              0      No         No      16
# 17    9959-WOFKT   Male              0      No        Yes      71
# 28    5248-YGIJN   Male              0     Yes         No      72
# 48    7639-LIAYI   Male              0      No         No      52
# 62    0526-SXDJP   Male              0     Yes         No      72
# ...          ...    ...            ...     ...        ...     ...
# 6951  9588-YRFHY   Male              0      No         No      49
# 6956  2451-YMUXS   Male              1      No         No      67
# 6995  7164-BPTUT   Male              0      No        Yes      57
# 7007  2274-XUATA   Male              1     Yes         No      72
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 11            Yes                No              No  No internet service  ...
# ...

# %%
ac.shape
# Out:
# (850, 21)

# %% [markdown]
# # how many  female person has contract two year?

# %%
ac=data[(data["Contract"]=="Two year")&(data["gender"]=="Female")]

# %%
ac
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 23    3638-WEABW  Female              0     Yes         No      58
# 30    3841-NFECX  Female              1     Yes         No      71
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# 41    9489-DEDVP  Female              0     Yes        Yes      70
# ...          ...     ...            ...     ...        ...     ...
# 7012  6691-CCIHA  Female              0     Yes         No      62
# 7017  4807-IZYOZ  Female              0      No         No      51
# 7019  9710-NJERN  Female              0      No         No      39
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7037  2569-WGERO  Female              0      No         No      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 15            Yes           Yes     Fiber optic                  Yes  ...
# ...

# %%
ac.shape
# Out:
# (845, 21)

# %% [markdown]
# # how many person has month to month contract?

# %%
ba=data[data['Contract']=='Month-to-month']

# %%
ba
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
ba.shape
# Out:
# (3875, 21)

# %% [markdown]
# # how many person has no internet service and churn yes?

# %%
ad=data[(data["InternetService"]=="No")&(data["Churn"]=="Yes")]

# %%
ad
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 22    1066-JKSGK    Male              0      No         No       1
# 97    0278-YXOOG    Male              0      No         No       5
# 268   6323-AYBRX    Male              0      No         No      59
# 385   4895-TMWIR    Male              1     Yes         No      11
# 408   4800-VHZKI  Female              0      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 6558  4488-PSYCG    Male              0      No         No      16
# 6609  1000-AJSLD    Male              0      No         No       1
# 6789  7839-QRKXN  Female              0      No         No       1
# 6792  4597-ELFTS    Male              0      No         No      56
# 6969  4745-LSPLO    Male              0      No         No       1
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 22            Yes            No              No  No internet service  ...
# ...

# %%
data['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %% [markdown]
# # how many person has fibreoptic and churn yes?

# %%
ak=data[(data["InternetService"]=="Fiber optic")&(data["Churn"]=="Yes")]

# %%
ak
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# ...          ...     ...            ...     ...        ...     ...
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4             Yes            No     Fiber optic             No  ...
# ...

# %%
ak.shape
# Out:
# (1297, 21)

# %% [markdown]
# # how many person dsl and churn yes?

# %%
pk=data[(data["InternetService"]=="DSL")&(data["Churn"]=="Yes")]

# %%
pk
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 20    8779-QRDMV    Male              1      No         No       1
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 29    8773-HHUOZ  Female              0      No        Yes      17
# ...          ...     ...            ...     ...        ...     ...
# 6999  2108-XWMPY    Male              0      No         No       3
# 7001  6304-IJFSQ    Male              0      No         No       3
# 7011  5482-NUPNA  Female              0      No         No       4
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes                No             DSL            Yes  ...
# ...

# %%
pk.shape
# Out:
# (459, 21)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# #

# %%
#describing the data
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # Label encoding the data

# %%
#importing the library
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
a=['customerID', 'gender','Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling','TotalCharges', 'Churn','PaymentMethod']

# %%
a[17]
# Out:
# 'PaymentMethod'

# %%
#converting the object into integer by label encoding
for i in range(len(a)):
    data[a[i]]=le.fit_transform(data[a[i]])

# %%
#checking the columns whether it has object or not
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   int32
#  1   gender            7043 non-null   int32
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int32
#  4   Dependents        7043 non-null   int32
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int32
#  7   MultipleLines     7043 non-null   int32
#  8   InternetService   7043 non-null   int32
#  9   OnlineSecurity    7043 non-null   int32
#  10  OnlineBackup      7043 non-null   int32
#  11  DeviceProtection  7043 non-null   int32
#  12  TechSupport       7043 non-null   int32
#  13  StreamingTV       7043 non-null   int32
#  14  StreamingMovies   7043 non-null   int32
#  15  Contract          7043 non-null   int32
# ...

# %%
#taking the x value
x=data.drop('Churn',axis=1)

# %%
#taking the y value
y=data['Churn']

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int32

# %%
#spliting the data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # importing machine learning model

# %%
#the y value is categorical importing the machine learning 
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()

# %%
log.fit(x_train,y_train)
# Out:
# C:\Users\Dharani\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=log.predict(x_test)
pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
#importing accuracy score
from sklearn.metrics import accuracy_score

# %%
#checking the accuracy score
accuracy_score(y_test,pred)*100
# Out:
# 80.26969481902059

# %%
#importing confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[923, 113],
#        [165, 208]], dtype=int64)

# %%
#classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1036
#            1       0.65      0.56      0.60       373
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.72      0.73      1409
# weighted avg       0.80      0.80      0.80      1409
